# %%
import pandas as pd

df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")

df.drop('state', axis=1, inplace=True)
df['month'] = pd.to_datetime(df['date'], format="%d.%m.%y").dt.month_name()
df.set_index('date', inplace=True)

print(df['cases'].sum())
# Out:
# 2307769

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")
df.drop('state', axis=1, inplace=True)
df['date'] = pd.to_datetime(df['date'], format="%d.%m.%y")
df['month'] = df['date'].dt.month
df.set_index('date', inplace=True)

df[df['month']==12]['cases'].plot()
plt.savefig('plot.png')

# %%
(df[df['month']==12])[['cases', 'deaths']].plot()
plt.savefig('plot.png')

# %%
import pandas as pd

df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")

df.drop('state', axis=1, inplace=True)
df.set_index('date', inplace=True)
df['ratio'] = df['deaths'] / df['cases']
print(df[df['ratio'] == df['ratio'].max()])
# Out:
#           cases  deaths     ratio
# date
# 10.03.20      7       1  0.142857

# %%
import pandas as pd

df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")

df.drop('state', axis=1, inplace=True)
df['date'] = pd.to_datetime(df['date'], format="%d.%m.%y")
df['month'] = df['date'].dt.month_name()
df.set_index('date', inplace=True)
month_user = input()
maxim = df[df["month"] ==month_user]['cases'].max()
print(df[df['cases'] == maxim])
# Out:
# April
#             cases  deaths  month
# date
# 2020-04-29   2334      77  April

# %%
import pandas as pd

data = {
   'ages': [14, 18, 24, 42],
   'heights': [165, 180, 176, 184]
}

df = pd.DataFrame(data, index=['James', 'Bob', 'Amy', 'Dave'])

print(df[(df['ages']>18) & (df['heights']>180)])
# Out:
#       ages  heights
# Dave    42      184

# %%
import pandas as pd

data = {
   'name': ['James', 'Billy', 'Bob', 'Amy', 'Tom', 'Harry'],
   'rank': [4, 1, 3, 5, 2, 6]
}

df = pd.DataFrame(data, index=data['name'])

sec = int(input())

print(df["name"][df["rank"] == sec])
# Out:
# 2
# Tom    Tom
# Name: name, dtype: object

# %%
import pandas as pd

data = {
   'name': ['James', 'Billy', 'Bob', 'Amy', 'Tom'],
   'number': ['1234', '5678', '2222', '1111', '0909']
}

df = pd.DataFrame(data, index = ["Ahmet", "Mehmet", "Serife", "Gizem", "Zeynep" ])
name = input()
print(df.loc[name])
# Out:
# Mehmet
# name      Billy
# number     5678
# Name: Mehmet, dtype: object

# %%
import pandas as pd

data = {
   'ages': [14, 18, 24, 42],
   'heights': [165, 180, 176, 184]
}

df = pd.DataFrame(data, index=['James', 'Bob', 'Amy', 'Dave'])

print(df["ages"])
# Out:
# James    14
# Bob      18
# Amy      24
# Dave     42
# Name: ages, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")

df.drop('state', axis=1, inplace=True)

df['month'] = pd.to_datetime(df['date'], format="%d.%m.%y").dt.month_name()

df.set_index('date', inplace=True)

print(df.head())
# Out:
#           cases  deaths    month
# date
# 25.01.20      1       0  January
# 26.01.20      1       0  January
# 27.01.20      0       0  January
# 28.01.20      0       0  January
# 29.01.20      0       0  January

# %%
import pandas as pd

data = {
   'ages': [14, 18, 24, 42],
   'heights': [165, 180, 176, 184]
}

df = pd.DataFrame(data, index=['James', 'Bob', 'Amy', 'Dave'])

print(df[["ages", "heights"]])
# Out:
#        ages  heights
# James    14      165
# Bob      18      180
# Amy      24      176
# Dave     42      184

# %%
import pandas as pd

data = {
   'ages': [14, 18, 24, 42],
   'heights': [165, 180, 176, 184]
}

df = pd.DataFrame(data, index=['James', 'Bob', 'Amy', 'Dave'])

# third row
print(df.iloc[2])

#first 3 rows
print(df.iloc[:3])

# rows 2 to 3
print(df.iloc[1:3])
# Out:
# ages        24
# heights    176
# Name: Amy, dtype: int64
#        ages  heights
# James    14      165
# Bob      18      180
# Amy      24      176
#      ages  heights
# Bob    18      180
# Amy    24      176

# %%
(df.groupby('month')['cases'].sum())
# Out:
# month
# 1           3
# 2          25
# 3        8555
# 4       41887
# 5       62644
# 6      119039
# 7      270120
# 8      210268
# 9      108584
# 10     114123
# 11     301944
# 12    1070577
# Name: cases, dtype: int64

# %%
(df.groupby('month')['cases'].sum()).plot(kind="bar")
plt.savefig('plot.png')

# %%
df
# Out:
#           cases  deaths     month
# date
# 25.01.20      1       0   January
# 26.01.20      1       0   January
# 27.01.20      0       0   January
# 28.01.20      0       0   January
# 29.01.20      0       0   January
# ...         ...     ...       ...
# 27.12.20  37555      62  December
# 28.12.20  41720     246  December
# 29.12.20  34166     425  December
# 30.12.20  32386     437  December
# 31.12.20  32264     574  December
#
# [342 rows x 3 columns]

# %%
import pandas as pd
data = {
    'a': [1, 2, 3],
    'b': [5, 8, 4]
}
df = pd.DataFrame(data)
df['c'] = df['a']+df['b']
print(df.iloc[2]['c'])
# Out:
# 7

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("https://www.sololearn.com/uploads/ca-covid.csv")

df.drop('state', axis=1, inplace=True)
df['date'] = pd.to_datetime(df['date'], format="%d.%m.%y")
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df.set_index('day', inplace=True)

df = df[df['month']==6]

df[['cases', 'deaths']].plot(kind="line", legend=True)
plt.xlabel('Days in June')
plt.ylabel('Number')
plt.savefig('plot.png')

# %%
df = df[df['month']==6]

df[['cases', 'deaths']].plot(kind="area", legend=True)
plt.xlabel('Days in June')
plt.ylabel('Number')
plt.suptitle("COVID-19 in June")
plt.savefig('plot.png')

# %%
df[df["month"]==6]["cases"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[df["month"]==6][["cases", "deaths"]].plot(kind="area", stacked=False)
plt.savefig('plot.png')

# %%
df[df["month"]==6][["cases", "deaths"]].plot(kind="scatter", x='cases', y='deaths')
plt.savefig('plot.png')

# %%
df.groupby('month')['cases'].sum().plot(kind="pie")
plt.savefig('plot.png')

# %%
data = {
    'sport': ["Soccer", "Tennis", "Soccer", "Hockey"],
    'players': [5, 4, 8, 20]
}
df = pd.DataFrame(data)
df.groupby('sport')['players'].sum().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='players'>
